# %%
import pandas as pd
import swifter
from shapely import geometry
from shapely import ops
import numpy as np
import geojson
import utm

# %%
road_list = ['residential', 'living_street', 'tertiary', 'trunk', 'secondary', 'primary', 'pedestrian',
                 'tertiary_link', 'trunk_link', 'primary_link', 'secondary_link']
road_dict = {k: v for v, k in enumerate(road_list)}

# %%
def load_map(path):
    with open(path, encoding="utf-8") as f:
        lines = geojson.load(f)
    Roads = []
    for allFeatures in lines.features:
        if 'highway' in allFeatures['properties']:
            roadinfo = allFeatures['properties']

            roadinfo['location'] = allFeatures['geometry']['coordinates']

            Roads.append(roadinfo)
    Roads = pd.DataFrame.from_dict(Roads)
    Roads = Roads[Roads.highway.isin(
            ['residential', 'living_street', 'tertiary', 'trunk', 'secondary', 'primary', 'pedestrian', 'tertiary_link',
             'trunk_link', 'primary_link', 'secondary_link'])]
    Roads = Roads.set_index('osm_id')
    print('Roads::', Roads.shape)
    return Roads

# %%
def utm_convert(row):
    ls = []
    for y in row['location']:
        ls.append(list(utm.from_latlon(y[1], y[0])[0:2]))
    return ls


def linestring(row):
    return geometry.LineString(row.utmLocation)

# %%
def get_roadtype(row, roadmap):
    airspeckCoords = [(row['gpsLatitude'], row['gpsLongitude'])]

    closestRoadstoCoords = ''
    airspeckCoordsUtm = [list(utm.from_latlon(*x))[0:2] for x in airspeckCoords]
    airspeckShapelyPoints = [geometry.Point(x) for x in airspeckCoordsUtm]

    for points in airspeckShapelyPoints:
        roadDistancesToPoint = [points.distance(x) for x in roadmap.locationLineString]
        minIdx = np.argmin(roadDistancesToPoint)
        minRoadType = roadmap.highway[minIdx]
        closestRoadstoCoords = minRoadType
        minRoadName = roadmap.name[minIdx]

    return closestRoadstoCoords

# %%
personal_df = pd.read_csv('DAPHNE_personal1.csv')
personal_df
# Out:
#                        timestamp       pm2_5  hour_of_day  day_of_week  \
# 0      2018-08-08 10:32:00+05:30  104.961243           10            2
# 1      2018-08-08 10:33:00+05:30  102.461466           10            2
# 2      2018-08-08 10:34:00+05:30  103.492459           10            2
# 3      2018-08-08 10:35:00+05:30  104.404641           10            2
# 4      2018-08-08 10:37:00+05:30   97.950285           10            2
# ...                          ...         ...          ...          ...
# 99994  2019-06-11 19:22:00+05:30    8.535691           19            1
# 99995  2019-06-11 19:22:00+05:30  119.362456           19            1
# 99996  2019-06-11 19:22:00+05:30  116.736907           19            1
# 99997  2019-06-11 19:23:00+05:30    7.682049           19            1
# 99998  2019-06-11 19:23:00+05:30  113.224140           19            1
#
#        humidity  gpsLongitude  gpsLatitude  closest_pm  dist_to_closest_pm  \
# 0          65.1     77.280082    28.569925         NaN            7.386666
# 1          65.1     77.280083    28.569923         NaN            7.386400
# 2          65.1     77.280125    28.569871         NaN            7.379688
# 3          65.1     77.280116    28.569908         NaN            7.383891
# 4          63.1     77.280090    28.569901         NaN            7.383842
# ...         ...           ...          ...         ...                 ...
# 99994      36.8     77.284703    28.372723   57.868361            6.297428
# 99995      19.4     77.238881    28.493935  189.893183            2.914443
# 99996      30.1     77.310558    28.491065         NaN            0.328183
# 99997      36.8     77.284706    28.372789   57.868361            6.291026
# 99998      30.1     77.310558    28.491064         NaN            0.328193
#
#           closest_pm_id  walk
# 0      595DA699CD9937A4     1
# 1      595DA699CD9937A4     1
# 2      595DA699CD9937A4     1
# 3      595DA699CD9937A4     1
# 4      595DA699CD9937A4     1
# ...                 ...   ...
# 99994  E786F1568F65C296    61
# 99995  5F9C8651F6135EDC    17
# 99996  3FB5C906EB38BF10    58
# 99997  E786F1568F65C296    61
# 99998  3FB5C906EB38BF10    58
#
# [99999 rows x 11 columns]

# %%
roads = load_map('PreProcessing\\osmfiles\\map_daphne_lines.geojson')
roads = roads.reset_index()
roads = roads[~roads.osm_id.str.startswith('node')]
roads = roads.set_index('osm_id')
roads
# Out:
# Roads:: (105760, 7)
#                           name        highway  z_order  \
# osm_id
# 5873630    Mahatma Gandhi Marg        primary        7
# 7892104                    NaN    residential        3
# 7892285          JNU Ring Road    residential        3
# 7892369                    NaN    residential        3
# 7892539                    NaN    residential        3
# ...                        ...            ...      ...
# 970731241                  NaN       tertiary        4
# 970867253                  NaN  living_street        0
# 971113904                  NaN    residential        3
# 971288935       GC Narang Road  living_street        0
# 972531641                  NaN       tertiary        4
#
#                                      other_tags  \
# osm_id
# 5873630    "int_ref"=>"AH1;AH2","oneway"=>"yes"
# 7892104                                     NaN
# 7892285                          "oneway"=>"no"
# 7892369                                     NaN
# 7892539                                     NaN
# ...                                         ...
# 970731241                       "oneway"=>"yes"
# 970867253                                   NaN
# 971113904                                   NaN
# 971288935                                   NaN
# 972531641                                   NaN
#
#                                                     location aerialway barrier
# osm_id
# 5873630    [[77.231616, 28.670095], [77.231406, 28.670701...       NaN     NaN
# 7892104    [[77.168017, 28.542604], [77.167931, 28.542702...       NaN     NaN
# 7892285    [[77.164378, 28.538396], [77.164562, 28.538801...       NaN     NaN
# 7892369    [[77.166393, 28.542961], [77.167262, 28.542641...       NaN     NaN
# 7892539    [[77.161606, 28.546969], [77.162471, 28.546283...       NaN     NaN
# ...                                                      ...       ...     ...
# 970731241  [[77.350013, 28.645067], [77.349966, 28.64513]...       NaN     NaN
# 970867253   [[77.177205, 28.683692], [77.176773, 28.683087]]       NaN     NaN
# 971113904   [[77.198809, 28.681899], [77.198404, 28.682453]]       NaN     NaN
# 971288935   [[77.209391, 28.694149], [77.211926, 28.693209]]       NaN     NaN
# 972531641    [[77.287807, 28.602303], [77.287922, 28.60218]]       NaN     NaN
#
# [105760 rows x 7 columns]

# %%
roads['utmLocation'] = roads.apply(lambda row: utm_convert(row), axis=1)
roads['locationLineString'] = roads.apply(lambda row: linestring(row), axis=1)
roads = roads.filter(['name', 'highway', 'location', 'utmLocation', 'locationLineString'])
print('applying roadtype')
personal_df['roadType'] = personal_df.swifter.apply(lambda row: get_roadtype(row, roads), axis=1)
fileName = 'DAPHNE_personal_RT.csv'
personal_df.to_csv(fileName)
# Out:
# applyng roadtype
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\miniconda3\envs\sm2\lib\site-packages\swifter\swifter.py in apply(self, func, axis, raw, result_type, args, **kwds)
#     339             with suppress_stdout_stderr_logging():
# --> 340                 tmp_df = func(sample, *args, **kwds)
#     341                 sample_df = sample.apply(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# <ipython-input-10-7d06e44f14a6> in <lambda>(row)
#       4 print('applyng roadtype')
# ----> 5 personal_df['roadType'] = personal_df.swifter.apply(lambda row: get_roadtype(row, roads), axis=1)
#       6 fileName = 'DAPHNE_personal_RT.csv'
#
# <ipython-input-7-a803e38fea7d> in get_roadtype(row, roadmap)
#       4     closestRoadstoCoords = ''
# ----> 5     airspeckCoordsUtm = [list(utm.from_latlon(*x))[0:2] for x in airspeckCoords]
#       6     airspeckShapelyPoints = [geometry.Point(x) for x in airspeckCoordsUtm]
#
# <ipython-input-7-a803e38fea7d> in <listcomp>(.0)
#       4     closestRoadstoCoords = ''
# ----> 5     airspeckCoordsUtm = [list(utm.from_latlon(*x))[0:2] for x in airspeckCoords]
#       6     airspeckShapelyPoints = [geometry.Point(x) for x in airspeckCoordsUtm]
#
# ~\miniconda3\envs\sm2\lib\site-packages\utm\conversion.py in from_latlon(latitude, longitude, force_zone_number, force_zone_letter)
#     243     if force_zone_number is None:
# --> 244         zone_number = latlon_to_zone_number(latitude, longitude)
#     245     else:
#
# ~\miniconda3\envs\sm2\lib\site-packages\utm\conversion.py in latlon_to_zone_number(latitude, longitude)
#     308
# --> 309     if 56 <= latitude < 64 and 3 <= longitude < 12:
#     310         return 32
#
# ~\miniconda3\envs\sm2\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7d06e44f14a6> in <module>
#       3 roads = roads.filter(['name', 'highway', 'location', 'utmLocation', 'locationLineString'])
#       4 print('applyng roadtype')
# ----> 5 personal_df['roadType'] = personal_df.swifter.apply(lambda row: get_roadtype(row, roads), axis=1)
#       6 fileName = 'DAPHNE_personal_RT.csv'
#       7 personal_df.to_csv(fileName)
#
# ~\miniconda3\envs\sm2\lib\site-packages\swifter\swifter.py in apply(self, func, axis, raw, result_type, args, **kwds)
#     356             # if not dask, use modin for string processing
#     357             elif (est_apply_duration > self._dask_threshold) and axis == 1:
# --> 358                 return self._modin_apply(func, axis, raw, result_type, *args, **kwds)
#     359             else:  # use pandas
#     360                 if self._progress_bar:
#
# ~\miniconda3\envs\sm2\lib\site-packages\swifter\swifter.py in _modin_apply(self, func, axis, raw, result_type, *args, **kwds)
#     273                 )
#     274             output_df = (
# --> 275                 md.DataFrame(self._obj)
#     276                 .apply(func, *args, axis=axis, raw=raw, result_type=result_type, **kwds)
#     277                 ._to_pandas()
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\pandas\dataframe.py in apply(self, func, axis, raw, result_type, args, **kwds)
#     289     def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwds):
#     290         axis = self._get_axis_number(axis)
# --> 291         query_compiler = super(DataFrame, self).apply(
#     292             func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds
#     293         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\pandas\base.py in apply(self, func, axis, broadcast, raw, reduce, result_type, convert_dtype, args, **kwds)
#     743         elif not callable(func) and not is_list_like(func):
#     744             raise TypeError("{} object is not callable".format(type(func)))
# --> 745         query_compiler = self._query_compiler.apply(
#     746             func,
#     747             axis,
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\backends\pandas\query_compiler.py in apply(self, func, axis, *args, **kwargs)
#    2346             return self._apply_text_func_elementwise(func, axis, *args, **kwargs)
#    2347         elif callable(func):
# -> 2348             return self._callable_func(func, axis, *args, **kwargs)
#    2349         elif isinstance(func, dict):
#    2350             return self._dict_func(func, axis, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\backends\pandas\query_compiler.py in _callable_func(self, func, axis, *args, **kwargs)
#    2443         """
#    2444         func = wrap_udf_function(func)
# -> 2445         new_modin_frame = self._modin_frame._apply_full_axis(
#    2446             axis, lambda df: df.apply(func, axis=axis, *args, **kwargs)
#    2447         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\engines\base\frame\data.py in _apply_full_axis(self, axis, func, new_index, new_columns, dtypes)
#    1300         The data shape may change as a result of the function.
#    1301         """
# -> 1302         return self.broadcast_apply_full_axis(
#    1303             axis=axis,
#    1304             func=func,
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\engines\base\frame\data.py in broadcast_apply_full_axis(self, axis, func, other, new_index, new_columns, apply_indices, enumerate_partitions, dtypes)
#    1692         )
#    1693         # Index objects for new object creation. This is shorter than if..else
# -> 1694         new_axes = [
#    1695             self._compute_axis_labels(i, new_partitions)
#    1696             if new_axis is None
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\engines\base\frame\data.py in <listcomp>(.0)
#    1693         # Index objects for new object creation. This is shorter than if..else
#    1694         new_axes = [
# -> 1695             self._compute_axis_labels(i, new_partitions)
#    1696             if new_axis is None
#    1697             else new_axis
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\engines\base\frame\data.py in _compute_axis_labels(self, axis, partitions)
#     257         if partitions is None:
#     258             partitions = self._partitions
# --> 259         return self._frame_mgr_cls.get_indices(
#     260             axis, partitions, lambda df: df.axes[axis]
#     261         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\modin\engines\ray\pandas_on_ray\frame\partition_manager.py in get_indices(cls, axis, partitions, index_func)
#     147                 else []
#     148             )
# --> 149         new_idx = ray.get(new_idx)
#     150         return new_idx[0].append(new_idx[1:]) if len(new_idx) else new_idx
#     151
#
# ~\AppData\Roaming\Python\Python38\site-packages\ray\worker.py in get(object_refs, timeout)
#    1369         global last_task_error_raise_time
#    1370         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1371         values, debugger_breakpoint = worker.get_objects(
#    1372             object_refs, timeout=timeout)
#    1373         for i, value in enumerate(values):
#
# ~\AppData\Roaming\Python\Python38\site-packages\ray\worker.py in get_objects(self, object_refs, timeout)
#     301
#     302         timeout_ms = int(timeout * 1000) if timeout else -1
# --> 303         data_metadata_pairs = self.core_worker.get_objects(
#     304             object_refs, self.current_task_id, timeout_ms)
#     305         debugger_breakpoint = b""
#
# python\ray\_raylet.pyx in ray._raylet.CoreWorker.get_objects()
#
# python\ray\_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:
